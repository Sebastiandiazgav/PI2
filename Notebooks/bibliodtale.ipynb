# %%
import pandas as pd

# %%
# Leemos archivo csv
homicidios = pd.read_csv('homicidio_df.csv')

# %%
homicidios
# Out:
#             ID  N_VICTIMAS     FECHA_x  AAAA_x  MM_x  DD_x  HH  \
# 0    2016-0001           1  2016-01-01    2016     1     1   4
# 1    2016-0002           1  2016-01-02    2016     1     2   1
# 2    2016-0003           1  2016-01-03    2016     1     3   7
# 3    2016-0005           1  2016-01-21    2016     1    21   5
# 4    2016-0008           1  2016-01-24    2016     1    24  18
# ..         ...         ...         ...     ...   ...   ...  ..
# 630  2021-0093           1  2021-12-13    2021    12    13  17
# 631  2021-0094           1  2021-12-20    2021    12    20   1
# 632  2021-0095           1  2021-12-30    2021    12    30   0
# 633  2021-0096           1  2021-12-15    2021    12    15  10
# 634  2021-0097           1  2021-11-18    2021    11    18   6
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  COMUNA  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA       8
# ...

# %%
# !pip install dtale
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 46.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 kB 33.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.7/219.7 kB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 50.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 77.0 MB/s eta 0:00:00
# ...

# %%
import dtale
import dtale.app as dtale_app


dtale_app.USE_COLAB = True

# %%
dtale.show(homicidios, host='localhost')
# Out:
# https://xk0ir1i3p3-496ff2e9c6d22116-40000-colab.googleusercontent.com/dtale/main/1

# %%
import requests
response = requests.get("https://www.google.com")
print(response.status_code)
# Out:
# 200
